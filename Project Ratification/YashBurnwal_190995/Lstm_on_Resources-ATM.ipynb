# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation, LeakyReLU, BatchNormalization, LSTM, Bidirectional, Input, Concatenate
from tensorflow.keras import backend
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns

# %%
pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 71kB 3.6MB/s
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %%
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
call_df=pd.read_csv('/content/drive/MyDrive/black_scholes_option_pricing/splitted_put.csv')
call_df=call_df.set_index(['Date'])
call_df=call_df[call_df['Close']>1]

# %%
call_df.head()
# Out:
#             Unnamed: 0  Unnamed: 0.1  ...  implied_volatility  Moneyness_put
# Date                                  ...
# 2013-12-31           0             0  ...            0.401503            OTM
# 2013-12-31           1             1  ...            0.331503            OTM
# 2013-12-31           2             2  ...            0.267503            OTM
# 2013-12-31           3             3  ...            0.213503            OTM
# 2013-12-31           4             4  ...            0.172503            OTM
#
# [5 rows x 12 columns]

# %%
spot_df=pd.read_csv('/content/drive/MyDrive/black_scholes_option_pricing/spot_price/^NSEI.csv')
spot_df.drop(['Open','High','Low','Close','Volume'],axis=1,inplace=True)
spot_df=spot_df.set_index(['Date'])
spot_df.dropna(inplace=True)

# %%
spot_df.head()
# Out:
#               Adj Close
# Date
# 2013-12-02  6217.850098
# 2013-12-03  6201.850098
# 2013-12-04  6160.950195
# 2013-12-05  6241.100098
# 2013-12-06  6259.899902

# %%
padded = np.insert(spot_df['Adj Close'].values, 0, np.array([np.nan] * 20))
rolled = np.column_stack([np.roll(padded, i) for i in range(20)])
rolled = rolled[~np.isnan(rolled).any(axis=1)]
rolled = np.column_stack((spot_df[19:], rolled))
price_history = pd.DataFrame(data=rolled)
price_history['date']=spot_df.index[19:]
price_history=price_history.set_index(['date'])
joined = call_df.join(price_history,how='inner')
joined.head(5)
# Out:
#             Unnamed: 0  Unnamed: 0.1  ...           19           20
# 2013-12-31           0             0  ...  6160.950195  6201.850098
# 2013-12-31           1             1  ...  6160.950195  6201.850098
# 2013-12-31           2             2  ...  6160.950195  6201.850098
# 2013-12-31           3             3  ...  6160.950195  6201.850098
# 2013-12-31           4             4  ...  6160.950195  6201.850098
#
# [5 rows x 33 columns]

# %%
joined_ITM = joined[joined["Moneyness_put"]=="ATM"]
joined_ITM.drop(["Moneyness_put"], axis=1, inplace=True)
joined = joined_ITM
call_ITM = call_df[call_df["Moneyness_put"]== "ATM"]
call_ITM = call_ITM.drop(["Moneyness_put"], axis=1)
joined.head(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#             Unnamed: 0  Unnamed: 0.1  ...           19           20
# 2013-12-31           5             5  ...  6160.950195  6201.850098
#
# [1 rows x 32 columns]

# %%
model_df=joined.drop(['return','volatility','bs_put'],axis=1)
model_df.head(1)
# Out:
#             Unnamed: 0  Unnamed: 0.1  ...           19           20
# 2013-12-31           5             5  ...  6160.950195  6201.850098
#
# [1 rows x 29 columns]

# %%
def split_data(df):
  call_X_train, call_X_test, call_y_train, call_y_test = train_test_split(df.drop(['Close'],axis=1).values,df['Close'].values,test_size=0.2,random_state=42)
  return call_X_train, call_X_test, call_y_train, call_y_test

# %%
call_X_train, call_X_test, call_y_train, call_y_test=split_data(model_df)
call_X_train.shape
# Out:
# (6625, 28)

# %%
N_TIMESTEPS = 20

call_X_train = [call_X_train[:, -N_TIMESTEPS:].reshape(call_X_train.shape[0], N_TIMESTEPS, 1), call_X_train[:, :4]]
call_X_test = [call_X_test[:, -N_TIMESTEPS:].reshape(call_X_test.shape[0], N_TIMESTEPS, 1), call_X_test[:, :4]]

call_X_train
# Out:
# [array([[[10482.200195],
#          [10585.200195],
#          [10598.400391],
#          ...,
#          [10584.75    ],
#          [10512.5     ],
#          [10472.5     ]],
#
#         [[12045.799805],
#          [12113.450195],
#          [12174.650391],
#          ...,
#          [12180.349609],
#          [12106.900391],
#          [12169.849609]],
#
#         [[11497.900391],
#          [11598.25    ],
#          [11712.25    ],
#          ...,
#          [11604.5     ],
#          [11665.950195],
#          [11598.      ]],
#
#         ...,
#
#         [[10792.5     ],
#          [10862.549805],
#          [10859.900391],
#          ...,
#          [10601.150391],
#          [10782.900391],
#          [10869.5     ]],
#
#         [[ 8475.75    ],
#          [ 8463.099609],
#          [ 8530.150391],
#          ...,
#          [ 8169.200195],
#          [ 8090.450195],
#          [ 8027.600098]],
#
#         [[ 9270.900391],
#          [ 9205.599609],
#          [ 9293.5     ],
#          ...,
#          [ 8748.75    ],
#          [ 8792.200195],
#          [ 8083.799805]]]),
#  array([[2.7280e+04, 2.7280e+04, 1.0550e+04, 1.7000e+01],
#         [3.9774e+04, 3.9774e+04, 1.2050e+04, 1.0000e+01],
#         [3.0970e+04, 3.0970e+04, 1.1400e+04, 5.5000e+01],
#         ...,
#         [2.8365e+04, 2.8365e+04, 1.0800e+04, 2.7000e+01],
#         [4.3170e+03, 4.3170e+03, 8.5000e+03, 6.4000e+01],
#         [4.4910e+04, 4.4910e+04, 9.3000e+03, 2.2000e+01]])]

# %%
layers = 4
n_timesteps = 20
features = 4
n_batch = 400
n_epochs = 50

# %%
import kerastuner as kt

# %%
def model(hp):
    close_history = Input((n_timesteps, 1))
    input2 = Input((features,))
    
    lstm = Sequential()
    lstm.add(LSTM(units=8, input_shape=(n_timesteps, 1), return_sequences=True))
    
    for i in range(hp.Int('num_layers',2,8)):
      lstm.add(LSTM(units=hp.Int('units_LSTM_'+str(i),min_value=4,max_value=14,step=2),return_sequences=True))

    
    lstm.add(LSTM(units=8,return_sequences=False))
    input1 = lstm(close_history)
    
    connect = Concatenate()([input1, input2])
    
    for i in range(hp.Int('num_layers_dense',2,10)):
        connect = Dense(units=hp.Int('units_Dense_' + str(i),
                                            min_value=32,
                                            max_value=640,
                                            step=32))(connect)
        connect = BatchNormalization()(connect)
        connect = LeakyReLU()(connect)
    
    predict = Dense(1, activation='relu')(connect)

    new_model= Model(inputs=[close_history, input2], outputs=predict)
    new_model.compile(optimizer=Adam(hp.Choice('learning_rate', [1e-3, 1e-4,1e-5])), loss='mse',metrics=['mse'])
    return new_model

# %%
tuner = kt.Hyperband(
    model,
    objective='mse',
    directory='/content/drive/MyDrive/Finance Project',
    project_name='HyperParameters_With_Resources',
    max_epochs=15,seed=42,
    factor=3)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project /content/drive/MyDrive/Finance Project/HyperParameters_With_Resources/oracle.json
# INFO:tensorflow:Reloading Tuner from /content/drive/MyDrive/Finance Project/HyperParameters_With_Resources/tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 21
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 8, 'step': 1, 'sampling': None}
# units_LSTM_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# units_LSTM_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# num_layers_dense (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 10, 'step': 1, 'sampling': None}
# units_Dense_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.001, 0.0001, 1e-05], 'ordered': True}
# units_LSTM_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# units_LSTM_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# units_LSTM_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# units_LSTM_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# units_Dense_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_Dense_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 640, 'step': 32, 'sampling': None}
# units_LSTM_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}
# units_LSTM_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 4, 'max_value': 14, 'step': 2, 'sampling': None}

# %%
tuner.search(call_X_train, call_y_train,epochs=15,validation_split=0.2)
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
best_model=tuner.hypermodel.build(best_hps)
best_model.fit(call_X_train, call_y_train, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 187/187 [==============================] - 35s 98ms/step - loss: 28326.1562 - mse: 28326.1562 - val_loss: 26439.8105 - val_mse: 26439.8105
# Epoch 2/20
# 187/187 [==============================] - 15s 78ms/step - loss: 24870.0820 - mse: 24870.0820 - val_loss: 15140.0859 - val_mse: 15140.0859
# Epoch 3/20
# 187/187 [==============================] - 15s 78ms/step - loss: 20499.5781 - mse: 20499.5781 - val_loss: 15966.7861 - val_mse: 15966.7861
# Epoch 4/20
# 187/187 [==============================] - 15s 79ms/step - loss: 16161.7246 - mse: 16161.7246 - val_loss: 13260.5576 - val_mse: 13260.5576
# Epoch 5/20
# 187/187 [==============================] - 15s 79ms/step - loss: 11996.5693 - mse: 11996.5693 - val_loss: 18151.4102 - val_mse: 18151.4102
# Epoch 6/20
# 187/187 [==============================] - 15s 79ms/step - loss: 8798.7334 - mse: 8798.7334 - val_loss: 23417.7656 - val_mse: 23417.7656
# Epoch 7/20
# 187/187 [==============================] - 15s 79ms/step - loss: 7255.1426 - mse: 7255.1426 - val_loss: 8965.1318 - val_mse: 8965.1318
# Epoch 8/20
# 187/187 [==============================] - 15s 80ms/step - loss: 5932.2852 - mse: 5932.2852 - val_loss: 10115.1143 - val_mse: 10115.1143
# Epoch 9/20
# 187/187 [==============================] - 15s 79ms/step - loss: 5752.5562 - mse: 5752.5562 - val_loss: 28232.8848 - val_mse: 28232.8848
# Epoch 10/20
# 187/187 [==============================] - 15s 79ms/step - loss: 5434.2544 - mse: 5434.2544 - val_loss: 20683.9102 - val_mse: 20683.9102
# Epoch 11/20
# 187/187 [==============================] - 15s 79ms/step - loss: 5234.9341 - mse: 5234.9341 - val_loss: 23730.7305 - val_mse: 23730.7305
# Epoch 12/20
# 187/187 [==============================] - 15s 81ms/step - loss: 5032.8613 - mse: 5032.8613 - val_loss: 8627.6172 - val_mse: 8627.6172
# Epoch 13/20
# 187/187 [==============================] - 15s 81ms/step - loss: 5207.7979 - mse: 5207.7979 - val_loss: 21869.8965 - val_mse: 21869.8965
# Epoch 14/20
# 187/187 [==============================] - 15s 80ms/step - loss: 4913.5850 - mse: 4913.5850 - val_loss: 22965.1680 - val_mse: 22965.1680
# Epoch 15/20
# 187/187 [==============================] - 15s 80ms/step - loss: 4727.7241 - mse: 4727.7241 - val_loss: 20512.1875 - val_mse: 20512.1875
# Epoch 16/20
# 187/187 [==============================] - 15s 79ms/step - loss: 4647.6162 - mse: 4647.6162 - val_loss: 25882.6934 - val_mse: 25882.6934
# Epoch 17/20
# 187/187 [==============================] - 15s 80ms/step - loss: 4522.8936 - mse: 4522.8936 - val_loss: 19997.9785 - val_mse: 19997.9785
# Epoch 18/20
# 187/187 [==============================] - 15s 80ms/step - loss: 4223.6909 - mse: 4223.6909 - val_loss: 3777.0366 - val_mse: 3777.0366
# Epoch 19/20
# 187/187 [==============================] - 15s 80ms/step - loss: 4164.2642 - mse: 4164.2642 - val_loss: 3867.5227 - val_mse: 3867.5227
# Epoch 20/20
# 187/187 [==============================] - 15s 79ms/step - loss: 4175.3594 - mse: 4175.3594 - val_loss: 20687.8398 - val_mse: 20687.8398

# %%
best_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 8)            8464        input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12)           0           sequential[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          2080        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160)          640         dense[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 160)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 192)          30912       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 192)          768         dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 192)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           12352       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 640)          41600       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 640)          2560        dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 640)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 576)          369216      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 576)          2304        dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 576)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 224)          129248      leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 224)          896         dense_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 224)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           14400       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64)           256         dense_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 64)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            65          leaky_re_lu_6[0][0]
# ==================================================================================================
# Total params: 616,017
# Trainable params: 612,177
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
best_model.save('/content/drive/MyDrive/black_scholes_option_pricing/HyperParameters_With_Resources/lstm_resource_model.h5')

# %%
y_pred_new=best_model.predict(call_X_test)
y_pred_new.shape
# Out:
# (1657, 1)

# %%
y_pred_new
# Out:
# array([[ 86.56585 ],
#        [ 33.95974 ],
#        [ 38.73599 ],
#        ...,
#        [172.87279 ],
#        [ 92.069374],
#        [  0.      ]], dtype=float32)

# %%
y_pred_train=best_model.predict(call_X_train)

# %%
y_pred_train.shape
# Out:
# (6625, 1)

# %%
call_X_train_tm, call_X_test_tm, call_y_train_tm, call_y_test_tm = train_test_split(call_df.drop(['Close'],axis=1),call_df['bs_put'],test_size=0.2,random_state=42)

# %%
call_y_test_tm
# Out:
# Date
# 2020-10-06     54.126364
# 2016-09-02     28.048132
# 2016-05-02      8.558845
# 2014-07-30    370.094769
# 2020-04-13     35.063440
#                  ...
# 2020-03-17    632.675043
# 2017-09-20    104.701435
# 2020-02-11    153.540536
# 2014-01-15      0.859090
# 2020-11-10    563.542718
# Name: bs_put, Length: 11000, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(list (call_X_test_tm["bs_put"]),y_pred_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-2b75eaebb4c7> in <module>()
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score(list (call_X_test_tm["bs_put"]),y_pred_new)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     575     """
#     576     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 577         y_true, y_pred, multioutput)
#     578     check_consistent_length(y_true, y_pred, sample_weight)
#     579
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [11000, 1657]

# %%
x=np.array(call_y_test).reshape(-1,1)
y=np.array(y_pred).reshape(-1,1)
reg=LinearRegression().fit(x,y_pred_new)
mae= mean_absolute_error(x,y_pred_new)
print(reg.score(x,y_pred_new),mae)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-0d3204accf3b> in <module>()
#       1 x=np.array(call_y_test).reshape(-1,1)
# ----> 2 y=np.array(y_pred).reshape(-1,1)
#       3 reg=LinearRegression().fit(x,y_pred_new)
#       4 mae= mean_absolute_error(x,y_pred_new)
#       5 print(reg.score(x,y_pred_new),mae)
#
# NameError: name 'y_pred' is not defined

# %%
r2_score(call_y_train,y_pred_train)
# Out:
# -1.0180613355392873

# %%
call_X_test_tm["bs_put"]
# Out:
# Date
# 2020-10-06     54.126364
# 2016-09-02     28.048132
# 2016-05-02      8.558845
# 2014-07-30    370.094769
# 2020-04-13     35.063440
#                  ...
# 2020-03-17    632.675043
# 2017-09-20    104.701435
# 2020-02-11    153.540536
# 2014-01-15      0.859090
# 2020-11-10    563.542718
# Name: bs_put, Length: 11000, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
print('mse: ',mean_absolute_error(call_y_test ,y_pred_new))
from sklearn.metrics import mean_squared_error
print('mae: ',mean_squared_error(call_y_test ,y_pred_new))
# Out:
# mse:  103.26240101090814
# mae:  21520.577827583915

# %%
x=np.array(call_y_test).reshape(-1,1)
y=np.array(y_pred_new).reshape(-1,1)
reg=LinearRegression().fit(x,y)
mae= mean_absolute_error(x,y)
plt.scatter(x,y)

# %%
print(reg.score(x,y))
